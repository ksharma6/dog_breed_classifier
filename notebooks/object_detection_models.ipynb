# %%
import os

os.chdir("/home/kishen/documents/python_projects/stanford_dogs/")
from src.data import BBDataset

# %%
root = '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation'
test = BBDataset(root)
test.__getitem__(3)
# Out:
# ('affenpinscher', array([  5,  38, 205, 374]))

# %%
test.__len__()
# Out:
# 20580

# %%
test.images_paths
# Out:
# ['/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10147',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10185',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10225',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10437',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10439',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10447',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10680',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10787',
#  '/home/kishen/documents/python_projects/stanford_dogs/data/Annotation/affenpinscher/n02110627_10848',
# ...
