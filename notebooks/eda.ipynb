# %%
import os
import matplotlib.pyplot as plt


os.chdir("/home/kishen/documents/python_projects/stanford_dogs/")
from src.data import ImageDataset

# %%
#read in image data
path = "/home/kishen/documents/python_projects/stanford_dogs/data/"
dataset = ImageDataset(root=path)

# %%
fig_path = "/home/kishen/documents/python_projects/stanford_dogs/notebooks/plots/rand_dogs1.png"

dataset.display_images(4, 4, figsize = (10,10))#, fig_path = fig_path)
