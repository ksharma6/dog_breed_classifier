# %%
import matplotlib.pyplot as plt
import os
import random
import torchvision

os.chdir("/home/kishen/documents/python_projects/stanford_dogs/")
from src.data import ImageDataset

# %%
#read in image data
path = "/home/kishen/documents/python_projects/stanford_dogs/data/Images"

dataset = ImageDataset(root_directory=path, transform=torchvision.transforms.ToTensor())

# %%
f_dict = {'fontsize': 16}
dataset.display_images(rows=5, cols = 4, num_images = 20, figsize= (15,15), fontdict = f_dict)

#save plot
path = "/home/kishen/documents/python_projects/stanford_dogs/notebooks/plots/"
plt.savefig(path + "rand_dogs.png")
